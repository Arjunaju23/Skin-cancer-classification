# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet import preprocess_input
import matplotlib.pyplot as plt

# %%
TARGET_SIZE = (224, 224)
BATCH_SIZE = 32

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    horizontal_flip=True,
    vertical_flip=True,
    rotation_range=20,  
    width_shift_range=0.20, 
    height_shift_range=0.20,
    zoom_range=0.20,
    brightness_range=[0.8, 1.2], 
    shear_range=0.1,  
    channel_shift_range=10.0
)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

train_gen = train_datagen.flow_from_directory(
    'Final_dataset/train',
    target_size=TARGET_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True
)

val_gen = test_datagen.flow_from_directory(
    'Final_dataset/val',
    target_size=TARGET_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
test_gen = test_datagen.flow_from_directory(
    'Final_dataset/test',
    target_size=TARGET_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 3000 images belonging to 3 classes.
# Found 1050 images belonging to 3 classes.
# Found 300 images belonging to 3 classes.

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras import regularizers

# BASE MODEL
baseModel = tf.keras.applications.EfficientNetB0(
    input_shape=(224,224,3),
    include_top=False,
    weights="imagenet"
)
total_layers = len(baseModel.layers)
for idx, layer in enumerate(baseModel.layers):
    if idx > 0.80 * total_layers: 
        layer.trainable = True
    else:
        layer.trainable = False
# Out:
# 2025-05-03 10:53:21.440206: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2025-05-03 10:53:21.440262: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2025-05-03 10:53:21.440274: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2025-05-03 10:53:21.440465: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-05-03 10:53:21.440488: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.optimizers import Adam

# Custom head
model = models.Sequential([
    baseModel,
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(),
    layers.Dense(512, activation='swish'),  
    layers.Dropout(0.6),
    layers.Dense(256, activation='swish'),
    layers.Dropout(0.6),
    layers.Dense(3, activation='softmax')
])

model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),  #
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       655,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,842,662 (18.47 MB)
#  Trainable params: 3,095,827 (11.81 MB)
#  Non-trainable params: 1,746,835 (6.66 MB)

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=5, monitor='val_loss'),
    tf.keras.callbacks.ModelCheckpoint(
        'EfficientNet.keras',
        save_best_only=True,
        monitor='val_loss'
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=2,
        min_lr=1e-5
    )
]

history = model.fit(
    train_gen,
    epochs=50,
    validation_data=val_gen,
    callbacks=callbacks,
    verbose=1
)
# Out:
# /Users/rajendarbore/Desktop/Sasi_Final/Skin_Env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 2025-05-03 10:53:28.533818: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.3894 - loss: 1.6941 - val_accuracy: 0.7124 - val_loss: 0.8843 - learning_rate: 1.0000e-04
# Epoch 2/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.5730 - loss: 1.2190 - val_accuracy: 0.7619 - val_loss: 0.7297 - learning_rate: 1.0000e-04
# Epoch 3/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 122s 1s/step - accuracy: 0.6152 - loss: 1.1138 - val_accuracy: 0.7800 - val_loss: 0.6796 - learning_rate: 1.0000e-04
# Epoch 4/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 110s 1s/step - accuracy: 0.6634 - loss: 0.9929 - val_accuracy: 0.8057 - val_loss: 0.6668 - learning_rate: 1.0000e-04
# Epoch 5/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 121s 1s/step - accuracy: 0.6744 - loss: 0.9296 - val_accuracy: 0.8048 - val_loss: 0.6668 - learning_rate: 1.0000e-04
# Epoch 6/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 134s 1s/step - accuracy: 0.7023 - loss: 0.8999 - val_accuracy: 0.8152 - val_loss: 0.6599 - learning_rate: 1.0000e-04
# Epoch 7/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 131s 1s/step - accuracy: 0.7166 - loss: 0.8616 - val_accuracy: 0.8181 - val_loss: 0.6565 - learning_rate: 1.0000e-04
# Epoch 8/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 129s 1s/step - accuracy: 0.7179 - loss: 0.8436 - val_accuracy: 0.8276 - val_loss: 0.6318 - learning_rate: 1.0000e-04
# Epoch 9/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 127s 1s/step - accuracy: 0.7330 - loss: 0.7985 - val_accuracy: 0.8305 - val_loss: 0.6204 - learning_rate: 1.0000e-04
# Epoch 10/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 126s 1s/step - accuracy: 0.7509 - loss: 0.7828 - val_accuracy: 0.8286 - val_loss: 0.6178 - learning_rate: 1.0000e-04
# Epoch 11/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - accuracy: 0.7659 - loss: 0.7325 - val_accuracy: 0.8400 - val_loss: 0.6055 - learning_rate: 1.0000e-04
# Epoch 12/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 94s 994ms/step - accuracy: 0.7449 - loss: 0.7691 - val_accuracy: 0.8286 - val_loss: 0.6106 - learning_rate: 1.0000e-04
# Epoch 13/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 119s 1s/step - accuracy: 0.8008 - loss: 0.6932 - val_accuracy: 0.8429 - val_loss: 0.5907 - learning_rate: 1.0000e-04
# Epoch 14/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - accuracy: 0.7985 - loss: 0.6754 - val_accuracy: 0.8438 - val_loss: 0.5784 - learning_rate: 1.0000e-04
# Epoch 15/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - accuracy: 0.8065 - loss: 0.6855 - val_accuracy: 0.8514 - val_loss: 0.5724 - learning_rate: 1.0000e-04
# Epoch 16/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 104s 1s/step - accuracy: 0.8057 - loss: 0.6699 - val_accuracy: 0.8543 - val_loss: 0.5661 - learning_rate: 1.0000e-04
# Epoch 17/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 127s 1s/step - accuracy: 0.8175 - loss: 0.6424 - val_accuracy: 0.8581 - val_loss: 0.5572 - learning_rate: 1.0000e-04
# Epoch 18/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.8236 - loss: 0.6302 - val_accuracy: 0.8552 - val_loss: 0.5592 - learning_rate: 1.0000e-04
# Epoch 19/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - accuracy: 0.8235 - loss: 0.6279 - val_accuracy: 0.8562 - val_loss: 0.5488 - learning_rate: 1.0000e-04
# Epoch 20/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 132s 1s/step - accuracy: 0.8247 - loss: 0.6153 - val_accuracy: 0.8600 - val_loss: 0.5537 - learning_rate: 1.0000e-04
# Epoch 21/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 131s 1s/step - accuracy: 0.8209 - loss: 0.6277 - val_accuracy: 0.8695 - val_loss: 0.5468 - learning_rate: 1.0000e-04
# Epoch 22/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 132s 1s/step - accuracy: 0.8458 - loss: 0.5949 - val_accuracy: 0.8657 - val_loss: 0.5594 - learning_rate: 1.0000e-04
# Epoch 23/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 110s 1s/step - accuracy: 0.8404 - loss: 0.6067 - val_accuracy: 0.8743 - val_loss: 0.5507 - learning_rate: 1.0000e-04
# Epoch 24/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 101s 1s/step - accuracy: 0.8399 - loss: 0.5860 - val_accuracy: 0.8743 - val_loss: 0.5426 - learning_rate: 5.0000e-05
# Epoch 25/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.8489 - loss: 0.5756 - val_accuracy: 0.8733 - val_loss: 0.5449 - learning_rate: 5.0000e-05
# Epoch 26/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 110s 1s/step - accuracy: 0.8524 - loss: 0.5713 - val_accuracy: 0.8743 - val_loss: 0.5365 - learning_rate: 5.0000e-05
# Epoch 27/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - accuracy: 0.8506 - loss: 0.5665 - val_accuracy: 0.8762 - val_loss: 0.5433 - learning_rate: 5.0000e-05
# Epoch 28/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 103s 1s/step - accuracy: 0.8531 - loss: 0.5784 - val_accuracy: 0.8705 - val_loss: 0.5289 - learning_rate: 5.0000e-05
# Epoch 29/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 100s 1s/step - accuracy: 0.8651 - loss: 0.5526 - val_accuracy: 0.8752 - val_loss: 0.5257 - learning_rate: 5.0000e-05
# Epoch 30/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 115s 1s/step - accuracy: 0.8606 - loss: 0.5636 - val_accuracy: 0.8790 - val_loss: 0.5285 - learning_rate: 5.0000e-05
# Epoch 31/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 114s 1s/step - accuracy: 0.8752 - loss: 0.5319 - val_accuracy: 0.8771 - val_loss: 0.5240 - learning_rate: 5.0000e-05
# Epoch 32/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - accuracy: 0.8659 - loss: 0.5506 - val_accuracy: 0.8781 - val_loss: 0.5271 - learning_rate: 5.0000e-05
# Epoch 33/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 122s 1s/step - accuracy: 0.8674 - loss: 0.5590 - val_accuracy: 0.8800 - val_loss: 0.5301 - learning_rate: 5.0000e-05
# Epoch 34/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 121s 1s/step - accuracy: 0.8850 - loss: 0.5339 - val_accuracy: 0.8829 - val_loss: 0.5147 - learning_rate: 2.5000e-05
# Epoch 35/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 136s 1s/step - accuracy: 0.8787 - loss: 0.5294 - val_accuracy: 0.8762 - val_loss: 0.5288 - learning_rate: 2.5000e-05
# Epoch 36/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 125s 1s/step - accuracy: 0.8892 - loss: 0.5176 - val_accuracy: 0.8886 - val_loss: 0.5198 - learning_rate: 2.5000e-05
# Epoch 37/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 120s 1s/step - accuracy: 0.8889 - loss: 0.5209 - val_accuracy: 0.8857 - val_loss: 0.5212 - learning_rate: 1.2500e-05
# Epoch 38/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 120s 1s/step - accuracy: 0.8847 - loss: 0.5237 - val_accuracy: 0.8867 - val_loss: 0.5216 - learning_rate: 1.2500e-05
# Epoch 39/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - accuracy: 0.8730 - loss: 0.5295 - val_accuracy: 0.8876 - val_loss: 0.5204 - learning_rate: 1.0000e-05

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(acc))

# Plot accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy', marker='o')
plt.plot(epochs_range, val_acc, label='Validation Accuracy', marker='x')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss', marker='o')
plt.plot(epochs_range, val_loss, label='Validation Loss', marker='x')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
loss, accuracy = model.evaluate(test_gen)

print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# /Users/rajendarbore/Desktop/Sasi_Final/LatestSkinVENV/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2025-05-04 17:39:16.307044: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 593ms/step - accuracy: 0.9135 - loss: 0.4715
# Test Loss: 0.4772
# Test Accuracy: 91.00%

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

Y_pred = model.predict(test_gen, verbose=1)
y_pred = np.argmax(Y_pred, axis=1)

y_true = test_gen.classes

class_labels = list(test_gen.class_indices.keys())
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 365ms/step

# %%
cm = confusion_matrix(y_true, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_labels,
            yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=class_labels))
# Out:
# Classification Report:
#
#                       precision    recall  f1-score   support
#
# basal cell carcinoma       0.96      0.93      0.94       100
#             melanoma       0.84      0.94      0.89       100
#                nevus       0.95      0.86      0.90       100
#
#             accuracy                           0.91       300
#            macro avg       0.91      0.91      0.91       300
#         weighted avg       0.91      0.91      0.91       300

# %%
from sklearn.metrics import confusion_matrix, classification_report, f1_score, precision_score, recall_score, roc_curve, auc, roc_auc_score

macro_f1 = f1_score(y_true, y_pred, average='macro')
weighted_f1 = f1_score(y_true, y_pred, average='weighted')
macro_precision = precision_score(y_true, y_pred, average='macro')
macro_recall = recall_score(y_true, y_pred, average='macro')
print(f"Macro F1-Score: {macro_f1:.4f}")
print(f"Weighted F1-Score: {weighted_f1:.4f}")
print(f"Macro Precision: {macro_precision:.4f}")
print(f"Macro Recall: {macro_recall:.4f}")
# Out:
# Macro F1-Score: 0.9105
# Weighted F1-Score: 0.9105
# Macro Precision: 0.9144
# Macro Recall: 0.9100

# %%
from sklearn.preprocessing import label_binarize
n_classes = len(class_labels) 

y_true_bin = label_binarize(y_true, classes=np.arange(n_classes))

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], Y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fpr["macro"], tpr["macro"], _ = roc_curve(y_true_bin.ravel(), Y_pred.ravel())
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

print("\nClass-wise AUC Scores:")
for i in range(n_classes):
    print(f"{class_labels[i]}: {roc_auc[i]:.4f}")

print(f"\nMacro-average AUC: {roc_auc['macro']:.4f}")

plt.figure(figsize=(8, 6))
colors = ['blue', 'red', 'green', 'orange']

for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=1.5,
             label=f'{class_labels[i]} (AUC = {roc_auc[i]:.2f})') 

plt.plot(fpr["macro"], tpr["macro"],
         label=f'Macro-average (AUC = {roc_auc["macro"]:.2f})',
         color='navy', linestyle=':', linewidth=2)


plt.plot([0, 1], [0, 1], 'k--', lw=1.5)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multi-class ROC Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# Class-wise AUC Scores:
# basal cell carcinoma: 0.9919
# melanoma: 0.9708
# nevus: 0.9749
#
# Macro-average AUC: 0.9795
